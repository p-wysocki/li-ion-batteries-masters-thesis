# %%
import data_import
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = data_import.read_data()

# %%
data['discharge (random walk)'][222][6][0]
# Out:
# array([35.40052, 35.38506, 35.38506, 35.38506, 35.38506, 35.40052,
#        35.40052, 35.43144, 35.43144, 35.46235, 35.47781, 35.52419,
#        35.52419, 35.57056, 35.57056, 35.61694, 35.61694, 35.66332,
#        35.66332, 35.7097 , 35.7097 , 35.74061, 35.74061])

# %% [markdown]
# ![obraz.png](attachment:obraz.png)

# %%
example_array = data['discharge (random walk)'][64][2]
print(example_array)
# Out:
# [[109690.29 109691.29 109692.29 109693.29 109694.29 109695.29 109696.29
#   109697.29 109698.29 109699.29 109700.29 109701.29 109702.29 109703.29
#   109704.29 109705.29 109706.29 109707.29 109708.29 109709.29 109710.29
#   109711.29 109712.29 109713.29 109714.29 109715.29 109716.29 109717.29
#   109718.29 109719.29 109720.29 109721.29 109722.29 109723.29 109724.29
#   109725.29 109726.29 109727.29 109728.29 109729.29 109730.29 109731.29
#   109732.29 109733.29 109734.29 109735.29 109736.29 109737.29 109738.29
#   109739.29 109740.29 109741.29 109742.29 109743.29 109744.29 109745.29
#   109746.29 109747.29 109748.29 109749.29 109750.29 109751.29 109752.29
#   109753.29 109754.29 109755.29 109756.29 109757.29 109758.29 109759.29
#   109760.29 109761.29 109762.29 109763.29 109764.29 109765.29 109766.29
#   109767.29 109768.29 109769.29 109770.29 109771.29 109772.29 109773.29
#   109774.29 109775.29 109776.29 109777.29 109778.29 109779.29 109780.29
# ...

# %%
plt.plot(data['discharge (random walk)'][224][4][0])
plt.show()

# %%
voltage = data['discharge (random walk)'][3][4][0]
abs_time = data['discharge (random walk)'][3][3][0]

plt.plot(abs_time, voltage, marker='o', linestyle='--', color='r', label='Voltage')

plt.xlabel('Absolute time [s]')
plt.ylabel('Voltage [V]') 
#plt.xticks(xi, x)
plt.title('Voltage over time')
plt.legend() 
plt.show()

# %%
current = data['discharge (random walk)'][224][6][0]
print(current)
plt.plot(abs_time, current, marker='o', linestyle='--', color='b', label='Current') 
plt.xlabel('x')
plt.ylabel('y') 
#plt.xticks(xi, x)
plt.title('Current over time')
plt.legend() 
plt.show()
# Out:
# [35.53965 35.53965 35.58603 35.58603 35.60148 35.60148 35.60148 35.60148
#  35.58603 35.58603 35.55511 35.55511 35.52419 35.50873 35.49327 35.49327
#  35.46235 35.46235 35.4469  35.4469  35.43144 35.43144 35.43144 35.43144
#  35.41598 35.41598 35.41598 35.41598 35.40052 35.40052 35.38506 35.3696
#  35.3696  35.35415 35.35415 35.33868 35.33868 35.32322 35.32322 35.32322
#  35.30777 35.2923  35.2923  35.27685 35.27685 35.26139 35.26139 35.24593
#  35.24593 35.23047 35.23047 35.21501 35.21501 35.19955 35.19955 35.1841
#  35.1841  35.16864 35.16864 35.15318 35.15318 35.13772 35.13772 35.12226
#  35.12226 35.1068  35.1068  35.07589 35.07589 35.06042 35.06042 35.02951
#  35.02951 35.01405 35.01405 34.99859 34.99859 34.98313 34.98313 34.96767
#  34.96767 34.95221 34.95221 34.93675 34.93675 34.9213  34.9213  34.90584
#  34.89038 34.87492 34.87492 34.85946 34.844   34.82854 34.82854 34.81308
#  34.81308 34.79763 34.78217 34.78217 34.76671 34.76671 34.75125 34.75125
# ...
